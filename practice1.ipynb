# %%
from qiskit import *
from qiskit.visualization import plot_histogram
import numpy as np
# %matplotlib inline

# %% [markdown]
# Note: The simulation results change every time we run the code as it is a probability, the collapsed state differs in each debug and so the count also changes.

# %% [markdown]
# Problem 1

# %%
circ1_1=QuantumCircuit(1)
circ1_1.h(0)

# %%
circ1_1.draw('mpl')

# %%
circ1_1.measure_all()
backend=Aer.get_backend('qasm_simulator')
job=execute(circ1_1,backend)
result=job.result()
counts=result.get_counts()
print("Result: ",counts)
plot_histogram(counts)
# Out:
# Result:  {'0': 518, '1': 506}

# %%
#plot_state_city(outputstate)

# %%
circ1_2=QuantumCircuit(1)
circ1_2.h(0)
circ1_2.x(0)

# %%
circ1_2.draw('mpl')

# %%
circ1_2.measure_all()
backend=Aer.get_backend('qasm_simulator')
job=execute(circ1_2,backend)
result=job.result()
counts=result.get_counts()
print("Result: ",counts)
plot_histogram(counts)
# Out:
# Result:  {'1': 509, '0': 515}

# %%
circ1_3=QuantumCircuit(1)
circ1_3.h(0)
circ1_3.x(0)
circ1_3.y(0)

# %%
circ1_3.draw('mpl')

# %%
circ1_3.measure_all()
backend=Aer.get_backend('qasm_simulator')
job=execute(circ1_3,backend)
result=job.result()
counts=result.get_counts()
print("Result: ",counts)
plot_histogram(counts)
# Out:
# Result:  {'1': 529, '0': 495}

# %% [markdown]
# Problem 2

# %%
circ2_1=QuantumCircuit(2)
circ2_1.h(0)
circ2_1.cx(0,1)

# %%
circ2_1.draw('mpl')

# %%
circ2_1.measure_all()
backend=Aer.get_backend('qasm_simulator')
job=execute(circ2_1,backend)
result=job.result()
counts=result.get_counts()
print("Result: ",counts)
plot_histogram(counts)
# Out:
# Result:  {'00': 518, '11': 506}

# %%
circ2_2=QuantumCircuit(2)
circ2_2.x(0)
circ2_2.h(0)
circ2_2.cx(0,1)

# %%
circ2_2.draw('mpl')

# %%
circ2_2.measure_all()
backend=Aer.get_backend('qasm_simulator')
job=execute(circ2_2,backend)
result=job.result()
counts=result.get_counts()
print("Result: ",counts)
plot_histogram(counts)
# Out:
# Result:  {'00': 537, '11': 487}

# %%
circ2_3=QuantumCircuit(2)
circ2_3.h(0)
circ2_3.x(1)
circ2_3.cx(0,1)

# %%
circ2_3.draw('mpl')

# %%
circ2_3.measure_all()
backend=Aer.get_backend('qasm_simulator')
job=execute(circ2_3,backend)
result=job.result()
counts=result.get_counts()
print("Result: ",counts)
plot_histogram(counts)
# Out:
# Result:  {'01': 501, '10': 523}

# %%
circ2_4=QuantumCircuit(2)
circ2_4.x(0)
circ2_4.x(1)
circ2_4.h(0)
circ2_4.cx(0,1)

# %%
circ2_4.draw('mpl')

# %%
circ2_4.measure_all()
backend=Aer.get_backend('qasm_simulator')
job=execute(circ2_4,backend)
result=job.result()
counts=result.get_counts()
print("Result: ",counts)
plot_histogram(counts)
# Out:
# Result:  {'10': 490, '01': 534}

# %% [markdown]
# Problem 3

# %%
circ3=QuantumCircuit(3)
circ3.h(0)
circ3.cx(0,1)
circ3.x(2)
circ3.z(0)
circ3.cx(1,2)
circ3.swap(0,2)
circ3.x(0)

# %%
circ3.draw('mpl')

# %%
circ3.measure_all()
backend=Aer.get_backend('qasm_simulator')
job=execute(circ3,backend)
result=job.result()
counts=result.get_counts()
print("Result: ",counts)
plot_histogram(counts)
# Out:
# Result:  {'000': 506, '111': 518}
